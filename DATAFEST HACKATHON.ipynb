# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")

# %%
full_df = df_train.append(df_test)

# %%
df_test.head()
# Out:
#    Entry_id  age  pay_schedule  home_owner  income  months_employed  \
# 0   3560428   61        weekly           0    3180                0
# 1   6934997   23        weekly           0    1540                6
# 2   5682812   40     bi-weekly           0    5230                0
# 3   6493191   32  semi-monthly           0    5260                3
# 4   8990111   61     bi-weekly           1    3270                0
#
#    years_employed  current_address_year  personal_account_m  \
# 0               6                     3                   2
# 1               0                     0                   7
# 2               6                     1                   2
# 3               0                     3                   1
# 4               4                     0                   4
#
#    personal_account_y  has_debt  amount_requested  risk_score  risk_score_2  \
# 0                   7         1               600       30150      0.738510
# 1                   1         1               450       34550      0.642993
# 2                   7         1               700       42150      0.665224
# 3                   4         1              1150       64050      0.652429
# 4                   3         1               400       61700      0.659736
#
#    risk_score_3  risk_score_4  risk_score_5  ext_quality_score  \
# 0      0.881027      0.713423      0.826402           0.730720
# 1      0.766554      0.595018      0.762284           0.531712
# 2      0.960832      0.767828      0.778831           0.792552
# 3      0.802433      0.593816      0.560389           0.569459
# 4      0.937287      0.852323      0.785698           0.632466
#
#    ext_quality_score_2  inquiries_last_month
# 0             0.630720                     9
# 1             0.531712                     7
# 2             0.592552                     8
# 3             0.369459                     3
# 4             0.732466                     7

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5392 entries, 0 to 5391
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Entry_id              5392 non-null   int64
#  1   age                   5392 non-null   int64
#  2   pay_schedule          5392 non-null   object
#  3   home_owner            5392 non-null   int64
#  4   income                5392 non-null   int64
#  5   months_employed       5392 non-null   int64
#  6   years_employed        5392 non-null   int64
#  7   current_address_year  5392 non-null   int64
#  8   personal_account_m    5392 non-null   int64
#  9   personal_account_y    5392 non-null   int64
#  10  has_debt              5392 non-null   int64
#  11  amount_requested      5392 non-null   int64
#  12  risk_score            5392 non-null   int64
#  13  risk_score_2          5392 non-null   float64
#  14  risk_score_3          5392 non-null   float64
#  15  risk_score_4          5392 non-null   float64
#  16  risk_score_5          5392 non-null   float64
#  17  ext_quality_score     5392 non-null   float64
#  18  ext_quality_score_2   5392 non-null   float64
#  19  inquiries_last_month  5392 non-null   int64
# dtypes: float64(6), int64(13), object(1)
# memory usage: 842.6+ KB

# %%
df_test.shape
# Out:
# (5392, 20)

# %%
df_train.shape
# Out:
# (12516, 21)

# %%
df_test.isnull().sum()
# Out:
# Entry_id                0
# age                     0
# pay_schedule            0
# home_owner              0
# income                  0
# months_employed         0
# years_employed          0
# current_address_year    0
# personal_account_m      0
# personal_account_y      0
# has_debt                0
# amount_requested        0
# risk_score              0
# risk_score_2            0
# risk_score_3            0
# risk_score_4            0
# risk_score_5            0
# ext_quality_score       0
# ext_quality_score_2     0
# inquiries_last_month    0
# dtype: int64

# %%
corr = df_train.corr()

# %%
corr
# Out:
#                       Entry_id       age  home_owner    income  \
# Entry_id              1.000000  0.001674   -0.002344 -0.013507
# age                   0.001674  1.000000    0.133687  0.173751
# home_owner           -0.002344  0.133687    1.000000  0.147731
# income               -0.013507  0.173751    0.147731  1.000000
# months_employed       0.014661 -0.101626    0.018484 -0.044470
# years_employed       -0.008881  0.181711    0.023364  0.097195
# current_address_year -0.002746  0.146980    0.177688  0.048199
# personal_account_m    0.001546 -0.009237    0.010494  0.011379
# personal_account_y   -0.011615  0.043375   -0.044700  0.001863
# has_debt              0.009282 -0.039205   -0.086891 -0.016620
# amount_requested     -0.002112  0.088569    0.039704  0.296007
# risk_score           -0.003692  0.169701    0.110235  0.176333
# risk_score_2          0.006861 -0.019758   -0.000833 -0.010499
# risk_score_3         -0.017663  0.113279    0.047717  0.062654
# risk_score_4          0.004465  0.064497   -0.147547  0.002825
# risk_score_5         -0.002202  0.099304   -0.085380  0.026979
# ext_quality_score     0.004144  0.034433    0.013117 -0.003207
# ext_quality_score_2   0.002180  0.037925    0.005813  0.000577
# inquiries_last_month -0.003409  0.046362    0.014225  0.049533
# e_signed             -0.004522 -0.084775   -0.054786  0.039160
#
#                       months_employed  years_employed  current_address_year  \
# Entry_id                     0.014661       -0.008881             -0.002746
# age                         -0.101626        0.181711              0.146980
# home_owner                   0.018484        0.023364              0.177688
# income                      -0.044470        0.097195              0.048199
# months_employed              1.000000       -0.194144             -0.055271
# years_employed              -0.194144        1.000000              0.339631
# current_address_year        -0.055271        0.339631              1.000000
# personal_account_m           0.207739       -0.053152              0.081847
# personal_account_y          -0.023665        0.185619              0.116587
# has_debt                    -0.004871       -0.001882              0.015887
# amount_requested            -0.043417        0.094241              0.067214
# risk_score                  -0.041778        0.096123              0.086974
# risk_score_2                 0.031067       -0.060066             -0.064426
# risk_score_3                -0.032631        0.067584              0.047827
# risk_score_4                -0.013331       -0.032767             -0.157666
# risk_score_5                -0.026016       -0.006258             -0.098582
# ext_quality_score           -0.006963        0.009021              0.003250
# ext_quality_score_2         -0.000484        0.036350              0.012006
# inquiries_last_month        -0.021979        0.008185              0.015498
# e_signed                    -0.000714        0.009607             -0.016873
#
#                       personal_account_m  personal_account_y  has_debt  \
# Entry_id                        0.001546           -0.011615  0.009282
# age                            -0.009237            0.043375 -0.039205
# home_owner                      0.010494           -0.044700 -0.086891
# income                          0.011379            0.001863 -0.016620
# months_employed                 0.207739           -0.023665 -0.004871
# years_employed                 -0.053152            0.185619 -0.001882
# current_address_year            0.081847            0.116587  0.015887
# personal_account_m              1.000000           -0.143268  0.245035
# personal_account_y             -0.143268            1.000000 -0.029645
# has_debt                        0.245035           -0.029645  1.000000
# amount_requested               -0.042454            0.051882 -0.008441
# risk_score                     -0.045303            0.013564 -0.029361
# risk_score_2                   -0.027033            0.027299 -0.038540
# risk_score_3                    0.021609            0.073417  0.000377
# risk_score_4                   -0.060572            0.013644  0.010143
# risk_score_5                   -0.031058            0.049019  0.009387
# ext_quality_score              -0.028694            0.041922 -0.022883
# ext_quality_score_2            -0.012365            0.038524 -0.006583
# inquiries_last_month           -0.018642            0.010592  0.008539
# e_signed                       -0.088811           -0.025547  0.032952
#
#                       amount_requested  risk_score  risk_score_2  \
# Entry_id                     -0.002112   -0.003692      0.006861
# age                           0.088569    0.169701     -0.019758
# home_owner                    0.039704    0.110235     -0.000833
# income                        0.296007    0.176333     -0.010499
# months_employed              -0.043417   -0.041778      0.031067
# years_employed                0.094241    0.096123     -0.060066
# current_address_year          0.067214    0.086974     -0.064426
# personal_account_m           -0.042454   -0.045303     -0.027033
# personal_account_y            0.051882    0.013564      0.027299
# has_debt                     -0.008441   -0.029361     -0.038540
# amount_requested              1.000000    0.291016      0.007397
# risk_score                    0.291016    1.000000      0.213145
# risk_score_2                  0.007397    0.213145      1.000000
# risk_score_3                  0.052377    0.099622      0.183195
# risk_score_4                  0.062586    0.115621      0.224979
# risk_score_5                  0.073372    0.130006      0.229172
# ext_quality_score             0.027035    0.103552      0.210772
# ext_quality_score_2           0.032841    0.106679      0.198172
# inquiries_last_month         -0.036641   -0.266299     -0.217230
# e_signed                      0.064944    0.082468      0.010032
#
#                       risk_score_3  risk_score_4  risk_score_5  \
# Entry_id                 -0.017663      0.004465     -0.002202
# age                       0.113279      0.064497      0.099304
# home_owner                0.047717     -0.147547     -0.085380
# income                    0.062654      0.002825      0.026979
# months_employed          -0.032631     -0.013331     -0.026016
# years_employed            0.067584     -0.032767     -0.006258
# current_address_year      0.047827     -0.157666     -0.098582
# personal_account_m        0.021609     -0.060572     -0.031058
# personal_account_y        0.073417      0.013644      0.049019
# has_debt                  0.000377      0.010143      0.009387
# amount_requested          0.052377      0.062586      0.073372
# risk_score                0.099622      0.115621      0.130006
# risk_score_2              0.183195      0.224979      0.229172
# risk_score_3              1.000000      0.163886      0.478213
# risk_score_4              0.163886      1.000000      0.585909
# risk_score_5              0.478213      0.585909      1.000000
# ext_quality_score         0.257891      0.248139      0.291352
# ext_quality_score_2       0.265341      0.234005      0.282420
# inquiries_last_month     -0.044728     -0.033884     -0.021691
# e_signed                 -0.028525      0.007270     -0.005864
#
#                       ext_quality_score  ext_quality_score_2  \
# Entry_id                       0.004144             0.002180
# age                            0.034433             0.037925
# home_owner                     0.013117             0.005813
# income                        -0.003207             0.000577
# months_employed               -0.006963            -0.000484
# years_employed                 0.009021             0.036350
# current_address_year           0.003250             0.012006
# personal_account_m            -0.028694            -0.012365
# personal_account_y             0.041922             0.038524
# has_debt                      -0.022883            -0.006583
# amount_requested               0.027035             0.032841
# risk_score                     0.103552             0.106679
# risk_score_2                   0.210772             0.198172
# risk_score_3                   0.257891             0.265341
# risk_score_4                   0.248139             0.234005
# risk_score_5                   0.291352             0.282420
# ext_quality_score              1.000000             0.362358
# ext_quality_score_2            0.362358             1.000000
# inquiries_last_month          -0.088726            -0.095113
# e_signed                      -0.029381            -0.021148
#
#                       inquiries_last_month  e_signed
# Entry_id                         -0.003409 -0.004522
# age                               0.046362 -0.084775
# home_owner                        0.014225 -0.054786
# income                            0.049533  0.039160
# months_employed                  -0.021979 -0.000714
# years_employed                    0.008185  0.009607
# current_address_year              0.015498 -0.016873
# personal_account_m               -0.018642 -0.088811
# personal_account_y                0.010592 -0.025547
# has_debt                          0.008539  0.032952
# amount_requested                 -0.036641  0.064944
# risk_score                       -0.266299  0.082468
# risk_score_2                     -0.217230  0.010032
# risk_score_3                     -0.044728 -0.028525
# risk_score_4                     -0.033884  0.007270
# risk_score_5                     -0.021691 -0.005864
# ext_quality_score                -0.088726 -0.029381
# ext_quality_score_2              -0.095113 -0.021148
# inquiries_last_month              1.000000 -0.031749
# e_signed                         -0.031749  1.000000

# %%
df_test.duplicated().sum()
# Out:
# 0

# %%
df_test.corr()
# Out:
#                       Entry_id       age  home_owner    income  \
# Entry_id              1.000000  0.010493    0.013849  0.001447
# age                   0.010493  1.000000    0.161409  0.174813
# home_owner            0.013849  0.161409    1.000000  0.146919
# income                0.001447  0.174813    0.146919  1.000000
# months_employed       0.017597 -0.108333    0.016900 -0.060135
# years_employed        0.017610  0.184636    0.036743  0.113837
# current_address_year  0.000698  0.145553    0.183013  0.044197
# personal_account_m   -0.005152 -0.023519    0.021293  0.003517
# personal_account_y    0.001377  0.036549   -0.052727 -0.011062
# has_debt              0.003281 -0.054469   -0.051415  0.001469
# amount_requested      0.010998  0.073486    0.020219  0.272399
# risk_score            0.031107  0.147018    0.121450  0.149822
# risk_score_2          0.029711 -0.017778    0.004055 -0.054155
# risk_score_3          0.022028  0.106751    0.054234  0.049477
# risk_score_4          0.012815  0.080143   -0.113377 -0.010879
# risk_score_5          0.021742  0.080602   -0.068947  0.020951
# ext_quality_score     0.010477  0.027296    0.002994 -0.020819
# ext_quality_score_2   0.016124  0.044846    0.004798 -0.012396
# inquiries_last_month -0.003779  0.028635    0.003867  0.057014
#
#                       months_employed  years_employed  current_address_year  \
# Entry_id                     0.017597        0.017610              0.000698
# age                         -0.108333        0.184636              0.145553
# home_owner                   0.016900        0.036743              0.183013
# income                      -0.060135        0.113837              0.044197
# months_employed              1.000000       -0.179656             -0.059779
# years_employed              -0.179656        1.000000              0.353847
# current_address_year        -0.059779        0.353847              1.000000
# personal_account_m           0.220822       -0.050939              0.084270
# personal_account_y          -0.010242        0.183090              0.095455
# has_debt                     0.009537        0.022078              0.020974
# amount_requested            -0.046233        0.061967              0.069584
# risk_score                  -0.051791        0.105548              0.098713
# risk_score_2                 0.024086       -0.048412             -0.051132
# risk_score_3                -0.005187        0.091016              0.084234
# risk_score_4                -0.017239       -0.021424             -0.168882
# risk_score_5                -0.003843        0.015564             -0.085152
# ext_quality_score           -0.013763        0.026420              0.003823
# ext_quality_score_2         -0.013660        0.016435              0.002423
# inquiries_last_month        -0.038588        0.021148              0.008940
#
#                       personal_account_m  personal_account_y  has_debt  \
# Entry_id                       -0.005152            0.001377  0.003281
# age                            -0.023519            0.036549 -0.054469
# home_owner                      0.021293           -0.052727 -0.051415
# income                          0.003517           -0.011062  0.001469
# months_employed                 0.220822           -0.010242  0.009537
# years_employed                 -0.050939            0.183090  0.022078
# current_address_year            0.084270            0.095455  0.020974
# personal_account_m              1.000000           -0.134480  0.251093
# personal_account_y             -0.134480            1.000000 -0.033177
# has_debt                        0.251093           -0.033177  1.000000
# amount_requested               -0.055049            0.051826 -0.008460
# risk_score                     -0.041260            0.025217  0.000627
# risk_score_2                   -0.015673            0.028135 -0.025816
# risk_score_3                    0.045594            0.092503  0.002776
# risk_score_4                   -0.061227            0.011123 -0.016747
# risk_score_5                   -0.040554            0.025773 -0.014195
# ext_quality_score               0.011928            0.035028 -0.018352
# ext_quality_score_2            -0.002043            0.008135 -0.014753
# inquiries_last_month           -0.050577           -0.012767 -0.024427
#
#                       amount_requested  risk_score  risk_score_2  \
# Entry_id                      0.010998    0.031107      0.029711
# age                           0.073486    0.147018     -0.017778
# home_owner                    0.020219    0.121450      0.004055
# income                        0.272399    0.149822     -0.054155
# months_employed              -0.046233   -0.051791      0.024086
# years_employed                0.061967    0.105548     -0.048412
# current_address_year          0.069584    0.098713     -0.051132
# personal_account_m           -0.055049   -0.041260     -0.015673
# personal_account_y            0.051826    0.025217      0.028135
# has_debt                     -0.008460    0.000627     -0.025816
# amount_requested              1.000000    0.290172      0.000618
# risk_score                    0.290172    1.000000      0.196822
# risk_score_2                  0.000618    0.196822      1.000000
# risk_score_3                  0.029171    0.116937      0.186565
# risk_score_4                  0.058744    0.131070      0.225887
# risk_score_5                  0.066847    0.131509      0.223697
# ext_quality_score             0.020633    0.087447      0.199463
# ext_quality_score_2           0.016571    0.111644      0.204815
# inquiries_last_month         -0.035060   -0.248895     -0.206362
#
#                       risk_score_3  risk_score_4  risk_score_5  \
# Entry_id                  0.022028      0.012815      0.021742
# age                       0.106751      0.080143      0.080602
# home_owner                0.054234     -0.113377     -0.068947
# income                    0.049477     -0.010879      0.020951
# months_employed          -0.005187     -0.017239     -0.003843
# years_employed            0.091016     -0.021424      0.015564
# current_address_year      0.084234     -0.168882     -0.085152
# personal_account_m        0.045594     -0.061227     -0.040554
# personal_account_y        0.092503      0.011123      0.025773
# has_debt                  0.002776     -0.016747     -0.014195
# amount_requested          0.029171      0.058744      0.066847
# risk_score                0.116937      0.131070      0.131509
# risk_score_2              0.186565      0.225887      0.223697
# risk_score_3              1.000000      0.171004      0.485650
# risk_score_4              0.171004      1.000000      0.593632
# risk_score_5              0.485650      0.593632      1.000000
# ext_quality_score         0.254316      0.233763      0.267852
# ext_quality_score_2       0.273782      0.247156      0.272668
# inquiries_last_month     -0.035136     -0.032933     -0.001065
#
#                       ext_quality_score  ext_quality_score_2  \
# Entry_id                       0.010477             0.016124
# age                            0.027296             0.044846
# home_owner                     0.002994             0.004798
# income                        -0.020819            -0.012396
# months_employed               -0.013763            -0.013660
# years_employed                 0.026420             0.016435
# current_address_year           0.003823             0.002423
# personal_account_m             0.011928            -0.002043
# personal_account_y             0.035028             0.008135
# has_debt                      -0.018352            -0.014753
# amount_requested               0.020633             0.016571
# risk_score                     0.087447             0.111644
# risk_score_2                   0.199463             0.204815
# risk_score_3                   0.254316             0.273782
# risk_score_4                   0.233763             0.247156
# risk_score_5                   0.267852             0.272668
# ext_quality_score              1.000000             0.353843
# ext_quality_score_2            0.353843             1.000000
# inquiries_last_month          -0.041419            -0.048468
#
#                       inquiries_last_month
# Entry_id                         -0.003779
# age                               0.028635
# home_owner                        0.003867
# income                            0.057014
# months_employed                  -0.038588
# years_employed                    0.021148
# current_address_year              0.008940
# personal_account_m               -0.050577
# personal_account_y               -0.012767
# has_debt                         -0.024427
# amount_requested                 -0.035060
# risk_score                       -0.248895
# risk_score_2                     -0.206362
# risk_score_3                     -0.035136
# risk_score_4                     -0.032933
# risk_score_5                     -0.001065
# ext_quality_score                -0.041419
# ext_quality_score_2              -0.048468
# inquiries_last_month              1.000000
